# %%
def say_hi():
    print("Hello user")

    say_hi()

# %%
def ask_age_and_check_eligibility():
    age=input("Enter your age: ")
    age=int(age)

    if age>=18:
        print("You are eligible to vote.")

    else:
        print("You are not eligible to vote.")

ask_age_and_check_eligibility()
ask_age_and_check_eligibility()
ask_age_and_check_eligibility()
# Out:
# You are eligible to vote.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 12
#       9         print("You are not eligible to vote.")
#      11 ask_age_and_check_eligibility()
# ---> 12 ask_age_and_check_eligibility()
#      13 ask_age_and_check_eligibility()
#
# Cell In[7], line 3, in ask_age_and_check_eligibility()
#       1 def ask_age_and_check_eligibility():
#       2     age=input("Enter your age: ")
# ----> 3     age=int(age)
#       5     if age>=18:
#       6         print("You are eligible to vote.")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def check_age_eligibility(age,domicile):
    if age>=18 and domicile=="lahore":
        print("You are eligible to vote.")

        return True
    else:
        
        return False
isEligible=check_age_eligibility(23,"lahore")
print(isEligible)
# Out:
# You are eligible to vote.
# True

# %%
def calculate_percentage(obt_marks,total_marks):
    calculate_percentage=(obt_marks/total_marks)*100
    print(calculate_percentage)
calculate_percentage(990,1100)
# Out:
# 90.0
