# %%
print("Hello World")
# Out:
# Hello World

# %%
name="Ali Haider"

print(name)
# Out:
# Ali Haider

# %%
obtainedMarks=679
totalMarks=1100

print(obtainedMarks)
print(totalMarks)

obtainedpercentage=(obtainedMarks/totalMarks)*100
print(obtainedpercentage)
# Out:
# 679
# 1100
# 61.727272727272734

# %%
height=679
weight=1100

print(height)
print(weight)

bmi=(weight/(height**2))
print(bmi)
# Out:
# 679
# 1100
# 0.002385904941209133

# %%
x=2
y=5
answer=x**y
print(answer)
answer=x%y
print(answer)
answer=x/y
print(answer)
# Out:
# 32
# 2
# 0.4

# %%
is_raining=True
if is_raining==True:
    print("It is raining")
else:
    print("The sun is shining")
# Out:
# It is raining

# %%
obtainedMarks=85
totalMarks=100
obtainedpercentage=(obtainedMarks/totalMarks)*100

if obtainedpercentage >= 50:
    print("you have passed")
# Out:
# you have passed

# %%
age=19
if age >= 18:
    print("You are eligible to vote")
else:
    print("Yoou are not eligible")
# Out:
# You are eligible to vote

# %%
grade='B'
if grade=='A':
    print("You have grade A")
elif grade=='B':
    print("You have grade B")
elif grade=='C' :
    print("You have grade C")
else:
    print("You have grade D")
# Out:
# You have grade B

# %%
username="alihaider868787"
password="12345678"

if username=="alihaider868787" and password=="12345678":
    print("Login successfully")
else:
    print("Not Logined ")
# Out:
# Login successfully

# %%
weight=45
height=58
print(height)
print(weight)

bmi=(weight/(height**2))
print(bmi)


if weight <= 24:
    print("underweight")
else:
    print("weight is correct" )
# Out:
# 58
# 45
# 0.0133769322235434
# weight is correct

# %%
is_sunny=False
is_hw_finished=True
if is_sunny==True and is_hw_finished==True:
    print("You can play outside")
else:
    print("Finish your homework first")
# Out:
# Finish your homework first

# %%
dinner_item='cake'
if dinner_item=='cake' or dinner_item=='icecream':
    print("You can have dinner")
# Out:
# You can have dinner

# %%
is_light_on=False

if not is_light_on:
    print("Good you are saving electricity")
else:
    print("Light is on")
# Out:
# Good you are saving electricity

# %%
attendence=69
is_assignment_submitted=True
if attendence >=75 and is_assignment_submitted==True:
    print("A student is allowed to sit in exam")
else:
    print("The studetnt is not allowed")
# Out:
# The studetnt is not allowed

# %%
day='monday'
is_raining=False
if (day=='saturday' or day=='sunday') and not is_raining:
    print("you can go out")
else:
    print("Except these two days you cant go out")
# Out:
# Except these two days you cant go out

# %%
is_raining=True
if is_raining==True:
    print("It is raining")
# Out:
# It is raining

# %%
age=19
if age >=18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
attendence=69
is_assignment_submitted=True
if attendence >=75 and is_assignment_submitted==True:
    print("A student is allowed to sit in exam")
else:
    print("The studetnt is not allowed")

# %%
username="alihaider78"
password="1234567" 
if username == "alihaider78" and password == "123456":
    print("Login Successfull")
else:
    print("Login Failed")
# Out:
# Login Failed

# %%
is_sunny=True
is_hw_finished=True
if is_sunny==True and is_hw_finished==False:
    print("You can play outside")
else:
    print("Do your homework first")
# Out:
# Do your homework first

# %%
is_light_on=False

if not is_light_on:
    print("Good you are saving light")
else:
    print("Turn lifht off")
# Out:
# Good you are saving light
