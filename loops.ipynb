# %%
for i in range(5):
    name=input("Enter your name: ")
    print("Hello "  +name)
# Out:
# Hello 20
# Hello
# Hello
# Hello
# Hello

# %%
for i in range(100,15,-7):

    print(i)
# Out:
# 100
# 93
# 86
# 79
# 72
# 65
# 58
# 51
# 44
# 37
# 30
# 23
# 16

# %%
for i in range(50):
    print(i)
    name="Ali"
    print("Hello " + name)
# Out:
# 0
# Hello Ali
# 1
# Hello Ali
# 2
# Hello Ali
# 3
# Hello Ali
# 4
# Hello Ali
# 5
# Hello Ali
# 6
# Hello Ali
# 7
# Hello Ali
# 8
# Hello Ali
# 9
# Hello Ali
# 10
# Hello Ali
# 11
# Hello Ali
# 12
# Hello Ali
# 13
# Hello Ali
# 14
# Hello Ali
# 15
# Hello Ali
# 16
# Hello Ali
# 17
# Hello Ali
# 18
# Hello Ali
# 19
# Hello Ali
# 20
# Hello Ali
# 21
# Hello Ali
# 22
# Hello Ali
# 23
# Hello Ali
# 24
# Hello Ali
# 25
# Hello Ali
# 26
# Hello Ali
# 27
# Hello Ali
# 28
# Hello Ali
# 29
# Hello Ali
# 30
# Hello Ali
# 31
# Hello Ali
# 32
# Hello Ali
# 33
# Hello Ali
# 34
# Hello Ali
# 35
# Hello Ali
# 36
# Hello Ali
# 37
# Hello Ali
# 38
# Hello Ali
# 39
# Hello Ali
# 40
# Hello Ali
# 41
# Hello Ali
# 42
# Hello Ali
# 43
# Hello Ali
# 44
# Hello Ali
# 45
# Hello Ali
# 46
# Hello Ali
# 47
# Hello Ali
# 48
# Hello Ali
# 49
# Hello Ali

# %%
obt_marks=input("Enter obt_marks")
obt_marks=int(obt_marks)
total_marks=input("Enter total_marks")
total_marks=int(total_marks)
percentage=(obt_marks/total_marks)*100
percentage
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 obt_marks=input("Enter obt_marks")
# ----> 2 obt_marks=int(obt_marks)
#       3 total_marks=input("Enter total_marks")
#       4 total_marks=int(total_marks)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
height=input("Enter height")
height=int(height)
weight=input("Enter weight")
weight=int(weight)
bmi=weight/(height**2)
bmi
# Out:
# 2.4

# %%
base=input("Enter base")
base=int(base)
height=input("Enter height")
height=int(height)
Area=(1/2*base*height)
Area
# Out:
# 1139.0

# %%
age="23"
print(type(age))

age = int(age)
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age=input("Enter your age: ")
print(type(age))
age = int(age)


while(age<=0):
    age=input("Please enter a valid age")
    age = int(age)

print(age)
# Out:
# <class 'str'>
# 18

# %%
user_password=input("Enter password")

correct_password="234"
while(user_password!=correct_password):
    user_password=input("Enter a valid password")
    print("Invalid password")
print(user_password)
# Out:
# Invalid password
# Invalid password
# 234

# %%
def say_hi():
    print("Hello user")
say_hi()
# Out:
# Hello user

# %%
def ask_age_and_check_eligibility():
    age=input("Enter your age: ")
    age=int(age)

    if age>=18:
        print("You are eligible to vote.")

    else:
        print("You are not eligible to vote.")
        
ask_age_and_check_eligibility()
# Out:
# You are eligible to vote.
