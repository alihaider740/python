# %%
names=['Ali','Joe','Doe','Boi']

print(names)
print(names[0])
print(names[1])
print(names[2])
print(names[3])
# Out:
# ['Ali', 'Joe', 'Doe', 'Boi']
# Ali
# Joe
# Doe
# Boi

# %%
names.append("Khan")

print(names)
# Out:
# ['Ali', 'Joe', 'Doe', 'Boi', 'Khan']

# %%
names.insert(1, "mike")

print(names)
# Out:
# ['Ali', 'mike', 'Ali', 'Joe', 'Doe', 'Boi', 'Khan']

# %%
names.remove("Joe")

print(names)
# Out:
# ['Ali', 'mike', 'Ali', 'Doe', 'Boi', 'Khan']

# %%
names.pop(0)

print(names)
# Out:
# ['mike', 'Ali', 'Doe', 'Boi', 'Khan']

# %%
print(names.index("Doe"))
# Out:
# 2

# %%
names=[]
for i in range(5):
    name = input("Enter name: ")

    names.append(name)
print(names)
# Out:
# ['1', '2', '3', '4', '5']

# %%
print(len(names))
# Out:
# 4

# %%
age=[3,4,5,6,6,7,8,9]

print(age.count(6))
# Out:
# 2

# %%
print(names.count("Boi"))
# Out:
# 1

# %%
students=["Ali","Doe","John"]
employees=["Hassan","Sarfaraz","Kashif"]

user_name=input("Enter your name: ")

if user_name  in students:
    print("Yes user is in students")
elif user_name in employees:
    print("Yes user is in employee")
else:
    print("User is not found in any list")
# Out:
# User is not found in any list

# %%
names=["John","Boi","Doe"]
age=[3,4,5,6,7,8]
names.reverse()
age.reverse()
print(names)
print(age)
# Out:
# ['Doe', 'Boi', 'John']
# [8, 7, 6, 5, 4, 3]

# %%
names=["John","Doe","Boi"]
abcd="Kashif"
print(abcd in names)
if abcd in names:
    print(f"{abcd} is in list")
# Out:
# False

# %%
ages=[23,45,67,90,13]

max_age=max(ages)
min_age=min(ages)

print(f"Max age: {max_age}")
print(f"Min age: {min_age}")
# Out:
# Max age: 90
# Min age: 13

# %%
name=["Ali","John"]

for nm in names:
    print(nm)
# Out:
# John
# Doe
# Boi

# %%
age=[1,2,3,4,55,44,66]
age=input("Enter your age")
age=int(age)
    
if age>=18:
    print("18 above")
else:
    print("Under 18")
# Out:
# Under 18

# %%
matrix=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]
print(matrix[1][2])
# Out:
# 6

# %%
matrix.append=

# %%
numbers=(1, 2, 3)
print(numbers)
# Out:
# (1, 2, 3)

# %%
person=("Alice", 34, "Haider")
print(person[0])
print(person[1])
# Out:
# Alice
# 34

# %%
coordinates = ((10,20),(30,40))
print(coordinates[1])

person[1]=26
# Out:
# (30, 40)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 coordinates = ((10,20),(30,40))
#       2 print(coordinates[1])
# ----> 4 person[1]=26
#
# TypeError: 'tuple' object does not support item assignment
